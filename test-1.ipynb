# %%
import bazi_calculator
import importlib
import bazi_calculator

importlib.reload(bazi_calculator)
# Out:
# <module 'bazi_calculator' from '/Users/xli/Documents/GitHub/bazi_api/bazi_calculator.py'>

# %%
input_json = {
  "birth": "1995-12-03",
  "time": "13:00",
  "tz": "Asia/Shanghai",
  "gender": "女"
}

data = input_json  # no need to json.loads

result = bazi_calculator.generate_summary(data)

# %%
result
# Out:
# {'bazi': {'年柱 Year Pillar': '乙亥',
#   '月柱 Month Pillar': '丁亥',
#   '日柱 Day Pillar': '戊辰',
#   '时柱 Hour Pillar': '己未'},
#  'fiveElementsScore': {'木': 2.7000000000000006,
#   '火': 2.7,
#   '土': 6.35,
#   '金': 0,
#   '水': 3.35},
#  'fiveElementsScore_eng': {'木 wood': 2.7000000000000006,
#   '火 fire': 2.7,
#   '土 earth': 6.35,
#   '金 metal': 0,
#   '水 water': 3.35},
#  'fiveElementsScore_adjusted': {'木': 3.24,
#   '火': 2.43,
#   '土': 5.08,
#   '金': 0.0,
#   '水': 4.355},
#  'fiveElementsScore_adjusted_eng': {'木 wood': 3.24,
#   '火 fire': 2.43,
#   '土 earth': 5.08,
#   '金 metal': 0.0,
#   '水 water': 4.355},
#  'fiveElementsState': {'木': '相', '火': '囚', '土': '死', '金': '休', '水': '旺'},
#  'fiveElementsState_eng': {'wood': 'Supporting / Growing',
#   'fire': 'Weak / Restricted',
#   'earth': 'Dormant / Fading',
#   'metal': 'Resting / Receding',
#   'water': 'Strong / Flourishing'},
#  'pillarsElements': ['乙(木) + 亥(水木)',
#   '丁(火) + 亥(水木)',
#   '戊(土) + 辰(土木水)',
#   '己(土) + 未(土火木)'],
# ...
